# %%
import pandas as pd
import plotly.io as pio

pio.renderers.default = "plotly_mimetype+notebook_connected"

# %%
df1 = pd.read_csv("IEA-EV-dataEV salesHistoricalCars.csv")
df2 = pd.read_csv("IEA-EV-dataEV stockHistoricalCars.csv")

# %%
df1
# Out:
#       Unnamed: 0.1  Unnamed: 0     Entity    category  \
# 0                0           0  Australia  Historical
# 1                1           1  Australia  Historical
# 2                2           2  Australia  Historical
# 3                3           3  Australia  Historical
# 4                4           4  Australia  Historical
# ...            ...         ...        ...         ...
# 2771          2771        2771      World  Historical
# 2772          2772        2772      World  Historical
# 2773          2773        2773      World  Historical
# 2774          2774        2774      World  Historical
# 2775          2775        2775      World  Historical
#
#                           parameter  mode powertrain  Year  \
# 0                          EV stock  Cars        BEV  2011
# 1                    EV stock share  Cars         EV  2011
# 2                    EV sales share  Cars         EV  2011
# 3                          EV sales  Cars        BEV  2011
# ...

# %%
df2
# Out:
#          region    category                      parameter  mode powertrain  \
# 0     Australia  Historical                       EV stock  Cars        BEV
# 1     Australia  Historical                 EV stock share  Cars         EV
# 2     Australia  Historical                 EV sales share  Cars         EV
# 3     Australia  Historical                       EV sales  Cars        BEV
# 4     Australia  Historical                       EV sales  Cars        BEV
# ...         ...         ...                            ...   ...        ...
# 2771      World  Historical           Oil displacement Mbd  Cars         EV
# 2772      World  Historical  Oil displacement, million lge  Cars         EV
# 2773      World  Historical                       EV sales  Cars        BEV
# 2774      World  Historical                 EV sales share  Cars         EV
# 2775      World  Historical                 EV stock share  Cars         EV
#
#       year                           unit         value
# ...

# %%
df1['BEV'] = df1['value'].where(df1['powertrain'] == 'BEV')
df1['PHEV'] = df1['value'].where(df1['powertrain'] == 'PHEV')
df1['EV'] = df1['value'].where(df1['powertrain'] == 'EV')

bev_average = df1['BEV'].mean()
phev_average = df1['PHEV'].mean()
ev_average = df1['EV'].mean()

bev_average, phev_average, ev_average
# Out:
# (184066.55869074492, 111392.55398457583, 474.2029905782906)

# %%
grouped_data = df1.groupby(['Year', 'Entity']).agg({
    'BEV': 'mean',
    'PHEV': 'mean',
    'EV': 'mean'
}).reset_index()

grouped_data
# Out:
#      Year          Entity         BEV       PHEV            EV
# 0    2010         Austria       350.0        NaN      0.007900
# 1    2010         Belgium        54.5        8.5      0.005650
# 2    2010           China      1350.0      340.0     66.302605
# 3    2010         Denmark        59.0       20.0      0.003700
# 4    2010            EU27      2100.0       24.5      0.006700
# ..    ...             ...         ...        ...           ...
# 447  2022     Switzerland     85000.0    45000.0     14.600000
# 448  2022         Turkiye     10500.0     1420.0      0.570000
# 449  2022             USA   1450000.0   525000.0   4281.822000
# 450  2022  United Kingdom    410000.0   250000.0     12.900000
# 451  2022           World  12650000.0  5400000.0  18003.306000
#
# [452 rows x 5 columns]

# %%
grouped_data = df1.drop('powertrain', axis=1).groupby('Year').mean()
grouped_data.reset_index(inplace=True)
grouped_data.head(6)
# Out:
# /var/folders/x4/z_h8ng_10bg46mhy6wv549jm0000gn/T/ipykernel_7658/3555266593.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#    Year  Unnamed: 0.1   Unnamed: 0         value           BEV          PHEV  \
# 0  2010   1429.650407  1429.650407    523.673410   1369.333333    105.312500
# 1  2011   1363.300578  1363.300578   1597.701593   3820.180328   1141.058824
# 2  2012   1351.913265  1351.913265   3783.660114   6900.890625   5787.215686
# 3  2013   1367.440758  1367.440758   6993.772582  12269.956522  11315.800000
# 4  2014   1373.059633  1373.059633  11778.547078  21328.267606  17675.457627
# 5  2015   1367.606987  1367.606987  19951.378536  36240.291667  28597.779412
#
#            EV
# 0   17.852088
# 1   58.658661
# 2   59.165213
# 3   76.896723
# 4  120.048442
# 5  167.591964

# %%
pivot_data = df1.pivot_table(index=['Year'], columns='parameter', values='value', aggfunc='mean')

pivot_data.reset_index(inplace=True)
pivot_data.head(6)
# Out:
# parameter  Year      EV sales  EV sales share      EV stock  EV stock share  \
# 0          2010    663.357143        0.039410   1355.484848        0.007967
# 1          2011   2488.326087        0.113106   3211.510204        0.012250
# 2          2012   4796.711864        0.258621   8103.553571        0.030380
# 3          2013   8100.333333        0.526368  15715.983607        0.057399
# 4          2014  12281.015152        0.904714  27290.812500        0.107627
# 5          2015  19879.112676        1.530656  45543.956522        0.198309
#
# parameter  Electricity demand  Oil displacement Mbd  \
# 0                      213.22              0.000113
# 1                      884.00              0.000436
# 2                      888.00              0.001002
# 3                     1170.00              0.002351
# 4                     1798.00              0.004375
# 5                     2486.00              0.007010
#
# parameter  Oil displacement, million lge
# ...

# %%
full_data = pd.merge(grouped_data, pivot_data, on=['Year'])
full_data
# Out:
#     Year  Unnamed: 0.1   Unnamed: 0          value            BEV  \
# 0   2010   1429.650407  1429.650407     523.673410    1369.333333
# 1   2011   1363.300578  1363.300578    1597.701593    3820.180328
# 2   2012   1351.913265  1351.913265    3783.660114    6900.890625
# 3   2013   1367.440758  1367.440758    6993.772582   12269.956522
# 4   2014   1373.059633  1373.059633   11778.547078   21328.267606
# 5   2015   1367.606987  1367.606987   19951.378536   36240.291667
# 6   2016   1378.739130  1378.739130   29699.795840   54775.916667
# 7   2017   1385.304348  1385.304348   45372.501549   86895.277778
# 8   2018   1391.869565  1391.869565   73218.091645  147503.333333
# 9   2019   1398.217949  1398.217949   95665.114352  205732.916667
# 10  2020   1404.910256  1404.910256  145776.714898  303811.694444
# 11  2021   1411.602564  1411.602564  253112.538719  536363.472222
# 12  2022   1418.294872  1418.294872  387805.528175  850701.111111
#
# ...

# %%
new_df = full_data.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
new_df
# Out:
#     Year          value            BEV           PHEV           EV  \
# 0   2010     523.673410    1369.333333     105.312500    17.852088
# 1   2011    1597.701593    3820.180328    1141.058824    58.658661
# 2   2012    3783.660114    6900.890625    5787.215686    59.165213
# 3   2013    6993.772582   12269.956522   11315.800000    76.896723
# 4   2014   11778.547078   21328.267606   17675.457627   120.048442
# 5   2015   19951.378536   36240.291667   28597.779412   167.591964
# 6   2016   29699.795840   54775.916667   41530.391304   241.461160
# 7   2017   45372.501549   86895.277778   60175.507246   304.554564
# 8   2018   73218.091645  147503.333333   89581.956522   435.573913
# 9   2019   95665.114352  205732.916667  104423.194444   604.408427
# 10  2020  145776.714898  303811.694444  169074.194444   710.747624
# 11  2021  253112.538719  536363.472222  284883.208333  1095.256226
# 12  2022  387805.528175  850701.111111  407161.708333  2004.117700
#
# ...

# %%
new_df.to_csv("new_df.csv")

# %%
data = pd.read_csv("data.csv")

# %%
data = data.drop(['Unnamed: 0'], axis=1)
data
# Out:
#             Entity Code  Year  Electric cars sold      Continent
# 0        Australia  AUS  2012                 250        Oceania
# 1        Australia  AUS  2013                 290        Oceania
# 2        Australia  AUS  2014                1320        Oceania
# 3        Australia  AUS  2015                1760        Oceania
# 4        Australia  AUS  2016                1370        Oceania
# ..             ...  ...   ...                 ...            ...
# 325  United States  USA  2018              360000  North America
# 326  United States  USA  2019              325000  North America
# 327  United States  USA  2020              294000  North America
# 328  United States  USA  2021              630000  North America
# 329  United States  USA  2022              990000  North America
#
# [330 rows x 5 columns]

# %%
new_df
# Out:
#     Year          value            BEV           PHEV           EV  \
# 0   2010     523.673410    1369.333333     105.312500    17.852088
# 1   2011    1597.701593    3820.180328    1141.058824    58.658661
# 2   2012    3783.660114    6900.890625    5787.215686    59.165213
# 3   2013    6993.772582   12269.956522   11315.800000    76.896723
# 4   2014   11778.547078   21328.267606   17675.457627   120.048442
# 5   2015   19951.378536   36240.291667   28597.779412   167.591964
# 6   2016   29699.795840   54775.916667   41530.391304   241.461160
# 7   2017   45372.501549   86895.277778   60175.507246   304.554564
# 8   2018   73218.091645  147503.333333   89581.956522   435.573913
# 9   2019   95665.114352  205732.916667  104423.194444   604.408427
# 10  2020  145776.714898  303811.694444  169074.194444   710.747624
# 11  2021  253112.538719  536363.472222  284883.208333  1095.256226
# 12  2022  387805.528175  850701.111111  407161.708333  2004.117700
#
# ...

# %%
merged_data = pd.merge(data, new_df, on=['Year'], how='left')

merged_data.head()
merged_data.to_csv("final_sales.csv")

# %%
merged_data
# Out:
#             Entity Code  Year  Electric cars sold      Continent  \
# 0        Australia  AUS  2012                 250        Oceania
# 1        Australia  AUS  2013                 290        Oceania
# 2        Australia  AUS  2014                1320        Oceania
# 3        Australia  AUS  2015                1760        Oceania
# 4        Australia  AUS  2016                1370        Oceania
# ..             ...  ...   ...                 ...            ...
# 325  United States  USA  2018              360000  North America
# 326  United States  USA  2019              325000  North America
# 327  United States  USA  2020              294000  North America
# 328  United States  USA  2021              630000  North America
# 329  United States  USA  2022              990000  North America
#
#              value            BEV           PHEV           EV       EV sales  \
# 0      3783.660114    6900.890625    5787.215686    59.165213    4796.711864
# ...

# %%
import pandas as pd
import plotly.graph_objs as go

df = merged_data
df['Year'] = df['Year'].astype(str)

def get_info(x):
    return x['Year'] + " : " + "{:.2f}".format(x["Electric cars sold"])

df["info"] = df.apply(get_info, axis=1)

grouped_df = df.groupby(['Entity', 'Code', 'Continent']).agg({
    'Electric cars sold': 'sum', 
    'info': lambda x: '<br>'.join(x)
}).reset_index()

traces = []
buttons = []
continents = grouped_df['Continent'].unique()

for continent in continents:
    continent_data = grouped_df[grouped_df['Continent'] == continent]
    trace = go.Choropleth(
        locations=continent_data['Code'],
        z=continent_data['Electric cars sold'],
        colorscale='Viridis',
        colorbar=dict(title='Number'),
        zmin=0,
        zmax=max(grouped_df['Electric cars sold']),
        showscale=True,
        reversescale=True,
        hoverinfo='text',
        text=[f"{name}<br>{other_info}<br>Total: {sales}"
              for name, other_info, sales in zip(continent_data['Entity'], continent_data['info'], continent_data['Electric cars sold'])],
        visible = (continent == continents[0])
    )
    traces.append(trace)
    
    buttons.append(dict(
        label=continent,
        method='update',
        args=[{'visible': [continent == c for c in continents]},
              {'title': f'Number of new electric cars sold 2010-2022 in {continent}',
               'showlegend': False}]
    ))

layout = go.Layout(
    title='Number of new electric cars sold 2010-2022',
    geo=dict(
        showcoastlines=False,
        showframe=False,
        projection=dict(type='natural earth')
    ),
    updatemenus=[{
        'buttons': buttons,
        'direction': 'down',
        'showactive': True,
    }]
)

fig = go.Figure(data=traces, layout=layout)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %% [markdown]
# ## Description

# %% [markdown]
# Before we dive into specific information such as electric vehicle registrations by state, charging station details by state, greenhouse gas emissions for specific countries, and customer satisfaction, we should first examine global electric vehicle sales.
# In the plot below, we have created an interactive world map that displays electric vehicle sales worldwide. The colors on the map represent the total electric vehicle sales for each country, with darker colors indicating higher sales volumes. You can select any country you are interested in by using the dropdown list to choose a continent you wish to visualize. Then, as you move your cursor over a country, you will see the total number of electric vehicle sales for each year from 2011 to 2022. For example, in the US, the total electric vehicle sales from 2011 to 2022 amounted to 3,353,800. The darker colors on the map suggest that countries like the US, China, Germany, the UK, France, Norway, Sweden, Japan, and the Netherlands are leading in electric vehicle sales.

# %%
df2 = pd.read_csv("IEA-EV-dataEV stockHistoricalCars.csv")

# %%
data = df2[df2['parameter'] == "EV sales"]

data.head()
# Out:
#        region    category parameter  mode powertrain  year      unit  value
# 3   Australia  Historical  EV sales  Cars        BEV  2011  Vehicles   49.0
# 4   Australia  Historical  EV sales  Cars        BEV  2012  Vehicles  170.0
# 9   Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles   80.0
# 10  Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles  100.0
# 15  Australia  Historical  EV sales  Cars        BEV  2013  Vehicles  190.0

# %%
df2
# Out:
#          region    category                      parameter  mode powertrain  \
# 0     Australia  Historical                       EV stock  Cars        BEV
# 1     Australia  Historical                 EV stock share  Cars         EV
# 2     Australia  Historical                 EV sales share  Cars         EV
# 3     Australia  Historical                       EV sales  Cars        BEV
# 4     Australia  Historical                       EV sales  Cars        BEV
# ...         ...         ...                            ...   ...        ...
# 2771      World  Historical           Oil displacement Mbd  Cars         EV
# 2772      World  Historical  Oil displacement, million lge  Cars         EV
# 2773      World  Historical                       EV sales  Cars        BEV
# 2774      World  Historical                 EV sales share  Cars         EV
# 2775      World  Historical                 EV stock share  Cars         EV
#
#       year                           unit         value
# ...

# %%
grouped_data = df2.groupby(['region', 'category', 'parameter', 'powertrain', 'year', 'unit'])['value'].mean().reset_index()

grouped_data.head()
# Out:
#       region    category parameter powertrain  year      unit  value
# 0  Australia  Historical  EV sales        BEV  2011  Vehicles   49.0
# 1  Australia  Historical  EV sales        BEV  2012  Vehicles  170.0
# 2  Australia  Historical  EV sales        BEV  2013  Vehicles  190.0
# 3  Australia  Historical  EV sales        BEV  2014  Vehicles  370.0
# 4  Australia  Historical  EV sales        BEV  2015  Vehicles  760.0

# %%
filtered_data = grouped_data[grouped_data['region'] != "World"]

filtered_data.head()
# Out:
#       region    category parameter powertrain  year      unit  value
# 0  Australia  Historical  EV sales        BEV  2011  Vehicles   49.0
# 1  Australia  Historical  EV sales        BEV  2012  Vehicles  170.0
# 2  Australia  Historical  EV sales        BEV  2013  Vehicles  190.0
# 3  Australia  Historical  EV sales        BEV  2014  Vehicles  370.0
# 4  Australia  Historical  EV sales        BEV  2015  Vehicles  760.0

# %%
filtered_data.to_csv("filtered.csv")

# %%
df5 = pd.read_csv("filtered.csv")
df5
# Out:
#       Unnamed: 0          region    category       parameter powertrain  year  \
# 0              0       Australia  Historical        EV sales        BEV  2011
# 1              1       Australia  Historical        EV sales        BEV  2012
# 2              2       Australia  Historical        EV sales        BEV  2013
# 3              3       Australia  Historical        EV sales        BEV  2014
# 4              4       Australia  Historical        EV sales        BEV  2015
# ...          ...             ...         ...             ...        ...   ...
# 2654        2654  United Kingdom  Historical  EV stock share         EV  2018
# 2655        2655  United Kingdom  Historical  EV stock share         EV  2019
# 2656        2656  United Kingdom  Historical  EV stock share         EV  2020
# 2657        2657  United Kingdom  Historical  EV stock share         EV  2021
# 2658        2658  United Kingdom  Historical  EV stock share         EV  2022
#
#           unit   value
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# df = pd.read_csv("IEA-EV-dataEV stockHistoricalCars.csv")
df5 = pd.read_csv("filtered.csv")

parameters = df5['parameter'].unique()
powertrains = df5['powertrain'].unique()

initial_parameter = parameters[0]
initial_powertrain = powertrains[0]

filtered_df = df5[(df5['parameter'] == initial_parameter) & (df5['powertrain'] == initial_powertrain)]

fig = make_subplots()

for region in filtered_df['region'].unique():
    Entity_df = filtered_df[filtered_df['region'] == region]
    fig.add_trace(go.Scatter(x=Entity_df['year'], y=Entity_df['value'], mode='lines', name=region))

fig.update_layout(xaxis_title='Year', yaxis_title='Value')

param_dropdown = {
    'buttons': [
        {
            'label': param,
            'method': 'update',
            'args': [{'visible': [p == param for p in df5['parameter']]}]
        } for param in parameters
    ],
    'direction': 'down',
    'showactive': True,
}

powertrain_dropdown = {
    'buttons': [
        {
            'label': powertrain,
            'method': 'update',
            'args': [{'visible': [p == powertrain for p in df5['powertrain']]}]
        } for powertrain in powertrains
    ],
    'direction': 'down',
    'showactive': True,
}

fig.update_layout(
    updatemenus=[
        {
            'buttons': param_dropdown['buttons'],
            'direction': param_dropdown['direction'],
            'showactive': param_dropdown['showactive'],
            'x': 0.0,
            'xanchor': 'left',
            'y': 1.1,
            'yanchor': 'top'
        },
        {
            'buttons': powertrain_dropdown['buttons'],
            'direction': powertrain_dropdown['direction'],
            'showactive': powertrain_dropdown['showactive'],
            'x': 0.15,
            'xanchor': 'left',
            'y': 1.1,
            'yanchor': 'top'
        }
    ]
)

fig.show()
# Out:
# <div>                            <div id="42c98ba7-5b8b-4b33-bbfe-66a3ca11881b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("42c98ba7-5b8b-4b33-bbfe-66a3ca11881b")) {                    Plotly.newPlot(                        "42c98ba7-5b8b-4b33-bbfe-66a3ca11881b",                        [{"mode":"lines","name":"Australia","x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[49.0,170.0,190.0,370.0,760.0,670.0,1200.0,1800.0,6300.0,5200.0,17000.0,33000.0],"type":"scatter"},{"mode":"lines","name":"Austria","x":[2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[650.0,1700.0,1700.0,3800.0,5400.0,6800.0,9300.0,16000.0,33000.0,34000.0],"type":"scatter"},{"mode":"lines","name":"Belgium","x":[2010,2011,2012,2013,2014,2015,2016,2017,
# ...

# %% [markdown]
# ## Description

# %% [markdown]
# The graph provides a clear view of each parameter and power system, and people can choose their preferred field from a drop-down list, with different categories producing different results.
# Right now, we want to focus on electric vehicle stocks in particular. By choosing powertrains of interest, such as plug-in hybrids, you can see that Germany has grown faster since 2019, while other countries have grown slower. Other notable aspects include electricity demand. For example, China has a lot of demand for electric vehicles, while Germany has a lot of demand for battery electric vehicles. Demand for plug-in hybrids appears to be higher in Europe and the United States. Whether it's PHEV, BEV or EV, demand will continue to grow over time.

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Load the CSV file
df_final_sales = pd.read_csv('final_sales.csv')

# Prepare the data
initial_metric = 'Electric cars sold'  # Let's choose a metric for visualization

# Create the figure
fig_sales = make_subplots()

# Add trace for each continent
for continent in df_final_sales['Continent'].unique():
    continent_df = df_final_sales[df_final_sales['Continent'] == continent]
    fig_sales.add_trace(go.Scatter(x=continent_df['Year'], y=continent_df[initial_metric], mode='lines', name=continent))

# Update layout for initial plot
fig_sales.update_layout(title=f'{initial_metric} by Continent', xaxis_title='Year', yaxis_title='Number of Electric Cars Sold')

# Metrics for dropdown (let's assume user might be interested in BEV, PHEV, and EV sales as well)
metrics = ['Electric cars sold', 'BEV', 'PHEV', 'EV sales']

# Create dropdown for metrics
metric_dropdown = {
    'buttons': [
        {
            'label': metric,
            'method': 'update',
            'args': [
                {'y': [
                    df_final_sales[df_final_sales['Continent'] == continent][metric] 
                    for continent in df_final_sales['Continent'].unique()
                ]},
                {'title': f'{metric} by Continent'}
            ]
        } for metric in metrics
    ],
    'direction': 'down',
    'showactive': True,
    'x': 0.0,
    'xanchor': 'left',
    'y': 1.1,
    'yanchor': 'top'
}

# Add dropdown to the figure
fig_sales.update_layout(
    updatemenus=[
        {
            'buttons': metric_dropdown['buttons'],
            'direction': metric_dropdown['direction'],
            'showactive': metric_dropdown['showactive'],
            'x': metric_dropdown['x'],
            'xanchor': metric_dropdown['xanchor'],
            'y': metric_dropdown['y'],
            'yanchor': metric_dropdown['yanchor']
        }
    ]
)

# Show the figure
fig_sales.show()
# Out:
# <div>                            <div id="5ce57d91-a34e-44b9-88dd-d28031b859dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ce57d91-a34e-44b9-88dd-d28031b859dc")) {                    Plotly.newPlot(                        "5ce57d91-a34e-44b9-88dd-d28031b859dc",                        [{"mode":"lines","name":"Oceania","x":[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[250,290,1320,1760,1370,2300,3600,9200,6900,20400,38900,15,27,36,320,500,1540,3440,5600,6900,5400,10300,28200],"type":"scatter"},{"mode":"lines","name":"Europe","x":[2015,2016,2017,2018,2019,2020,2021,2022,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2011,2012,2013,2014,2015,2016,2017,201
# ...

# %%
df_final_sales = pd.read_csv('final_sales.csv')
df_final_sales
# Out:
#      Unnamed: 0         Entity Code  Year  Electric cars sold      Continent  \
# 0             0      Australia  AUS  2012                 250        Oceania
# 1             1      Australia  AUS  2013                 290        Oceania
# 2             2      Australia  AUS  2014                1320        Oceania
# 3             3      Australia  AUS  2015                1760        Oceania
# 4             4      Australia  AUS  2016                1370        Oceania
# ..          ...            ...  ...   ...                 ...            ...
# 325         325  United States  USA  2018              360000  North America
# 326         326  United States  USA  2019              325000  North America
# 327         327  United States  USA  2020              294000  North America
# 328         328  United States  USA  2021              630000  North America
# 329         329  United States  USA  2022              990000  North America
#
# ...

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd

# Load the CSV file
df_final_sales = pd.read_csv('final_sales.csv')  # Make sure to provide the correct path to the file

# Create the figure
fig_sales = make_subplots()

# Add a trace for each country for the 'BEV' metric
for country in df_final_sales['Entity'].unique():
    country_df = df_final_sales[df_final_sales['Entity'] == country]
    fig_sales.add_trace(go.Scatter(
        x=country_df['Year'], 
        y=country_df['BEV'],  # Assuming 'BEV' is the name of the column you want to plot
        mode='lines', 
        name=f"{country} - BEV",
        visible=True  # Set all 'BEV' traces to be visible
    ))

# Update layout for initial plot
fig_sales.update_layout(title='BEV by Country', xaxis_title='Year', yaxis_title='BEV')

# Metrics for dropdown (excluding 'BEV' since it's already visible)
metrics = ['EV', 'PHEV', 'EV sales', 'EV sales share', 'EV stock', 
           'EV stock share', 'Electricity demand', 'Oil displacement Mbd', 
           'Oil displacement, million lge']

# Create a button for each metric, and update the visibility of the traces
buttons = []
for i, metric in enumerate(metrics):
    visibility = [metric == m for country in df_final_sales['Entity'].unique() for m in metrics]
    button = dict(
        label=metric,
        method='update',
        args=[{'visible': visibility},
              {'title': f'{metric} by Country',
               'yaxis': {'title': metric}}],
    )
    buttons.append(button)

# Add dropdown to the figure
fig_sales.update_layout(
    updatemenus=[{
        'buttons': buttons,
        'direction': 'down',
        'showactive': True,
        'x': 0.0,
        'xanchor': 'left',
        'y': 1.1,
        'yanchor': 'top'
    }]
)

# Show the figure
fig_sales.show()
# Out:
# <div>                            <div id="82b0fc6d-fd05-468b-ad91-81a83de79196" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("82b0fc6d-fd05-468b-ad91-81a83de79196")) {                    Plotly.newPlot(                        "82b0fc6d-fd05-468b-ad91-81a83de79196",                        [{"mode":"lines","name":"Australia - BEV","visible":true,"x":[2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"y":[6900.890625,12269.95652173913,21328.2676056338,36240.29166666666,54775.91666666666,86895.27777777778,147503.33333333334,205732.91666666663,303811.69444444444,536363.4722222222,850701.1111111111],"type":"scatter"},{"mode":"lines","name":"Austria - BEV","visible":true,"x":[2015,2016,2017,2018,2019,2020,2021,2022],"y":[36240.29166666666,54775.916
# ...
